# %%
import numpy as np
import re
from keras.utils import np_utils
from keras.models import Model, load_model
from keras.optimizers import Adam
from keras.preprocessing.text import Tokenizer
from keras.callbacks import LambdaCallback
from keras.callbacks import ModelCheckpoint

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# We import a previous mid-trained model
loaded_model = load_model('/content/drive/MyDrive/Modelos/4LSTM_ADAM_MIXED_CAP_CHECKPOINT.h5')

# %%
# Check the model structure
loaded_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, None)]            0
# _________________________________________________________________
# embedding (Embedding)        (None, None, 100)         1861100
# _________________________________________________________________
# lstm (LSTM)                  (None, None, 256)         365568
# _________________________________________________________________
# dropout (Dropout)            (None, None, 256)         0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, None, 256)         525312
# _________________________________________________________________
# dropout_1 (Dropout)          (None, None, 256)         0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, None, 256)         525312
# _________________________________________________________________
# dropout_2 (Dropout)          (None, None, 256)         0
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 256)               525312
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense (Dense)                (None, 18611)             4783027
# =================================================================
# Total params: 8,585,631
# Trainable params: 8,585,631
# Non-trainable params: 0
# _________________________________________________________________

# %%
# We load the text that will be used to train the model, this should be the same we used for the first training
with open ('/content/drive/MyDrive/Modelos/mixed_text.txt', encoding='utf-8-sig') as f:
    text = f.read()
seq_length = 20
# text lenght should be the same as well
text = text[:int(len(text)/2.75)]
start_story = '| ' * seq_length
text = start_story + text

# %%
def clean_text(text):
    """This function will clean a text in order to make it suitable for the LSTM model"""
    #text = text.lower()
    text = text.replace('\n', ' ')
    text = re.sub('   +', '. ', text).strip()
    text = text.replace('..', '.')
    # This pattern will insert a space before any punctuation sign in order to also tokenize them
    text = re.sub('([!"#$%&()*+,-./:;<=>?@[\]^_`{|}~])', r' \1 ', text)
    text = re.sub('\s{2,}', ' ', text)

    return text

# %%
# Clean the text
text = clean_text(text)

# %%
# We create a Tokenizer object
# The tokenizer object should have the exact same parameters we used for the first training in order to stay in tune 
tokenizer = Tokenizer(char_level = False, filters = '', lower = False)
# We fit our object with our text
tokenizer.fit_on_texts([text])
# We check how many words/tokens were found (+1 due zero indexing)
total_words = len(tokenizer.word_index) + 1
# We create a sequence of token labels for our text
token_list = tokenizer.texts_to_sequences([text])[0]

# %%
def generate_sequences(token_list, step, seq_length):
    """This function will generate a list of sequences from a tokenized text given a specific sequence length and a step"""
    X = []
    y = []

    # Given a specific tokenized text, X will save a word-sequence of n length and y will save the next word for that sequence
    for i in range(0, len(token_list) - seq_length, step):
        X.append(token_list[i: i + seq_length])
        y.append(token_list[i + seq_length])
    
    # y must be turned into categorical
    y = np_utils.to_categorical(y, num_classes = total_words)
    
    num_seq = len(X)
    print('Number of sequences:', num_seq, "\n")
    
    return X, y, num_seq

# %%
X, y, num_seq = generate_sequences(token_list, step = 1, seq_length = 20)
# Out:
# Number of sequences: 149045

# %%
# We convert our list of lists into a matrix so our model can read them
X = np.array(X)

# %%
# Consider waiting a couple seconds before running this cell after the previous one due RAM usage
y = np.array(y)

# %%
def sample_with_temp(preds, temperature=1.0):
    """This function gets the predictions generated by a model and returns the best fit choosen a given temperature"""
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    # creates a random experiment given the probabilities for ou next word
    probas = np.random.multinomial(1, preds, 1)
    # return the word with more probability in our experiment 
    return np.argmax(probas)



def generate_text(seed_text, next_words, model, max_sequence_len, temp):
    """This function will generate a text of a given size using the predictions created by our model"""
    output_text = seed_text
    
    seed_text = start_story + seed_text
    
    for _ in range(next_words):
      # Tokenize the seed text
        token_list = tokenizer.texts_to_sequences([seed_text])[0]
        token_list = token_list[-max_sequence_len:]
        token_list = np.reshape(token_list, (1, max_sequence_len))
        
        # get the predictions
        probs = model.predict(token_list, verbose=0)[0]
        # get the most probable next word 
        y_class = sample_with_temp(probs, temperature = temp)
        
        # if probability = 0 returns no word
        if y_class == 0:
            output_word = ''
        # if the probability is not 0     
        else:
            output_word = tokenizer.index_word[y_class]
            
        #if output_word == "|":
            #break
            
        output_text += output_word + ' '
        seed_text += output_word + ' '

    return output_text

# %%
def on_epoch_end(epoch, logs):
    """This function will generate a text prediction after each epoch"""
    seed_text = ""
    gen_words = 100

    print('Temp 0.2')
    print (generate_text(seed_text, gen_words, loaded_model, seq_length, temp = 0.2))
    print('Temp 0.33')
    print (generate_text(seed_text, gen_words, loaded_model, seq_length, temp = 0.33))
    print('Temp 0.5')
    print (generate_text(seed_text, gen_words, loaded_model, seq_length, temp = 0.5))

# This function will save our model after each epoch, only if it outperformed its previous loss score
filepath = '/content/drive/MyDrive/Modelos/4LSTM_ADAM_MIXED22_CAP_CHECKPOINT.h5'
checkpoint = ModelCheckpoint(filepath, monitor='loss', verbose=1, save_best_only=True, mode='min')

# %%
# Start the re-training 
# batch size must stay the same 
epochs = 200
batch_size = 32
num_batches = int(len(X) / batch_size)
callback = LambdaCallback(on_epoch_end=on_epoch_end)
callbacks_list = [callback, checkpoint]
loaded_model.fit(X, y, epochs=epochs, batch_size=batch_size, callbacks = callbacks_list, shuffle = True)
# Out:
# Epoch 1/200
# 4658/4658 [==============================] - 133s 23ms/step - loss: 1.1418
# Temp 0.2
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in log
#   This is separate from the ipykernel package so we can avoid doing imports until
# El pasado domingo , el segundo 11 de junio , no se lo de unos , de dos días , hasta otras mujeres para lograr tanto su papel sería quizá razón con la muerte . A lo largo de veinte años la inflación siempre se le han dado que una iniciativa gubernamental y una tragedia . También bien juntos para hacer una nueva idea de que los recursos son más grande de manera económica . Las empresas más de otra parte . El modelo político igual que un grupo de estímulo se dará de formas tiempo en los estados del
# Temp 0.33
# La democracia consiste en partidos de instituciones de Covid . Qué día como un aumento de un niño que se haya abra . Por contraste , no sólo rebasan una de telecomunicaciones presidencial confiado en que la dignidad , se gastarán la vida de los pobres . Que el mismo tiempo se bajó sin duda esos o de propósito a la libertad . Me ha preguntamos también lejos de un grupo de franca , se suele de un liderazgo de tres años y el norte popular de las campañas que se habían desarrollado . Fue una acción fue sacar a
# Temp 0.5
# El presidente viernes , 15 de enero el Instituto Nacional Electoral ( INE ) acordó censurar al Presidente de la República . Nueve de la Administración manera intervención ( véase : https : / / bit . ly / 3lNJqBr ) . < > Ahora bien , a largo de unos meses a la crisis electoral , Luis trata , tal y entre los más de poderes de la Casa Blanca . < > Por este contexto , si el gran momento del siglo histórico se cuenta como una gran comisión de salud en la economía nacional . < >
#
# Epoch 00001: loss improved from inf to 1.14185, saving model to /content/drive/MyDrive/Modelos/4LSTM_ADAM_MIXED22_CAP_CHECKPOINT.h5
# Epoch 2/200
# 4658/4658 [==============================] - 358s 77ms/step - loss: 1.1421
# Temp 0.2
# El mercado energético tejano rebasa la sueños que señala en ella como un gobierno de derecho ; de Sedesol , en el caso de Enrique Peña Nieto en la presidencia . En su vez más reciente : la reforma económica nacional del poder ha sido 1 . Es donde se involucré con la Secretaría de Salud para ser salvar una depreciación más distinta , la resolución de reformar la consulta nacional en medio de la regulación . < > La Cuarta Transformación será un punto de vista se había intentado presionar a medio de la creación de un nuevo proceso
# Temp 0.33
# El pasado domingo en la crisis económica de verse que lo dejó de ser lo que al Presidente se ha ido llamó su sentencia de forma públicas . Si la regulación , es un tema que tiene una auténtica semana , México está mal . ¿Qué cerca de mejorar el gasto para tener ellos . Para AMLO así , es probable dos años , pero después de que , la pobreza o más preocupante del tema . Las necesidades del dinero mexicano que se parece de los temas de desarrollo pública . Una pugna más no puede ser , como
# Temp 0.33
# El pasado domingo en la crisis política y una república es la de la democracia " . La vigencia de la izquierda , la política de la que se comparte los problemas para contar con la humanidad de la región . La verdad se acabó en la de las varias el crecimiento económico que se llevarán a un caso de elección . La mentira del odio . Las imágenes de López Obrador se dio a cada discurso de dignidad y de persona a 2000 de Washington en la pandemia contra el fin de aprobar el mismo día de parte de
# Temp 0.5
# El pasado domingo de México pública , es una de las la razón que se pregunten . 5 ( Acción ) , el consumo de diálogo que ahora se trata de una visión de recursos a la cuarta necesidad de hacer un país que se trata de un mandatario de tres años en la idea de un país de control gubernamental e incrementar la soberanía nacional para luchar una esperanza de resolver que se trata de un partido político . Quizás se ha mencionado el libreto en los años , en tantos ámbitos se fueron débiles . | | |
#
# Epoch 00009: loss improved from 1.10699 to 1.09264, saving model to /content/drive/MyDrive/Modelos/4LSTM_ADAM_MIXED22_CAP_CHECKPOINT.h5
# Epoch 10/200
# 4658/4658 [==============================] - 162s 35ms/step - loss: 1.0915
# Temp 0.2
# El pasado viernes , 15 de enero de 2020 , la Secretaría de Seguridad Ciudadana de la Ciudad de México y la Coordinación de Estado de seguridad . Pero se van más de eso muy grave específicamente me podría hacer crecer más es en evitar que son mejorar un pacto ? o Echeverría cita sólo el mismo que tuvo una idea que se está . Ante hace que la democracia se dice en la exposición religiosa y ganar una vez que la salud en la que supuestamente nos sufriendo más más relevante . Pero bien tiene que saber si no
# Temp 0.33
# La visita del exgobernador de Coahuila contra Sergio Aguayo debe topar con la razón y el derecho . La jurisprudencia vigente se inclina en favor de la libertad de expresión ejercida por el periodista . Sin embargo , soplan vientos autoritarios que a un liderazgo final de 1968 , después de una nueva ética de salud que ha hecho temerariamente al partido de derecha . Eso se encuentran de lograr que sea allá de los precios de recursos se han reducido con una posición política . En un régimen de números pública entre un solo día : una nueva filtración
# Temp 0.5
# Los malos tráileresde película son aquellos que echan a perder el final de la trama . En aquel arranque de aquel desaforado , se les reducido fueron difícil el poder de derecha , así como mucho para cumplir durante las asimetrías de la prueba de los votos . Un país está en todo , pero es nuestro consecuente crítico es un antídoto mal " . Para todos así , hay bien recordar que , , el Presidente no ha sido muy importante ni ni siquiera más temible en la verdad en la discriminación , que se ríe de un punto
#
# Epoch 00010: loss improved from 1.09264 to 1.09150, saving model to /content/drive/MyDrive/Modelos/4LSTM_ADAM_MIXED22_CAP_CHECKPOINT.h5
# Epoch 11/200
# 4658/4658 [==============================] - 165s 35ms/step - loss: 1.0815
# Temp 0.2
# El pasado viernes , 15 de enero de 2020 , el Presidente no reapareció . Agradeció los últimos tres mujeres . México se que Wilbert difícil de argumentos que quiere ser una idea especial más . ZOOM . Dado la familia que se trata del pueblo y el PAN . Lo mismo que los recursos que se mantengan otro que la industria fuera exterior . El presidente Hugo Chávez tiempo como mentir , hasta un millón de injusticia que le dice que no es una fuerza neoliberal o sus . No pueden permitir . Los datos son un cambio que
# Temp 0.33
# La idea del exgobernador de Coahuila contra Sergio Aguayo debe topar con la razón . Morena es un escenario tanto una semana tuve el poder presidencial para el país se desprenden . El poder laboral no se genera desde una frase sino que el poder es la corrupción . | | | | | | | | | | | | | | | | | | | | El día de ayer , fueron detenidos dos hombres por haber participado , presuntamente para lo que suele ser tengan durante sus ideas . Cada servicio se puso sobre atrás .
# Temp 0.5
# El pasado viernes , Andrés Manuel López Obrador , inició una gira de agradecimiento por el país . Parece que seguimos en cambio de los más de gobierno se encuentra de duda en su casa y su marido en materia que los mejores mexicanos del artículo contrario para la carta de Texcoco : a pesar de los instituciones de acuerdo con el fin de apoyo para lo que realmente se encuentra en quienes no se encuentran de manera . Pero sea siquiera quien hay ningún entorno anterior que un acosador , ni lo mismo es una ideología de cambio .
#
# Epoch 00020: loss did not improve from 1.03320
# Epoch 21/200
# 4658/4658 [==============================] - 358s 77ms/step - loss: 1.0314
# Temp 0.2
# El presidente literalmente privatiza nuestra vida social en la materia del nuevo régimen de los últimos años ( que es ) para intentan vulnerables contra todo se valiosa gubernamentales y y argumento o de acuerdo . Fue el atractivo que se haya presentado con una mala persona , sino el criterio de un que está de mujeres civiles , sin tener su Suena poco con una obligación de producir un mandato político y un espíritu país para trabajar sin intereses donde se tiene una economía positiva en las que la autosuficiencia se ha dado más fuerte y de tener algunas
# Temp 0.33
# La democracia consiste en partidos de buena manera de agradecimiento en calidad de un año que se hacen de acuerdo con una policía de todas luces electorales . A los próximos mexicanos los electos en los Estados Unidos están a sus denuncias con la población que le les pagó telecomunicaciones para de sus propias de sus predecesores , sin los requisitos anti al gobierno . < > < > En contraste , el mismo 45 de López Obrador no ha mordido la Constitución desde encima de la creación de información serían Santa transición que cualquier gobierno debe ser una administración
# Temp 0.5
# La conformación de un bloque opositor , entre el PAN , PRI y PRD , constituye una excelente noticia para su padre ; sino que uno de sus críticos supuestamente y “Lo que estén graves o todos la voz . No importa la idea de un tipo de crecimiento que se acaba de fondo y lo cual realmente se está en esta vida comercial . Las empresas sociales que se exportan . Como acabó invaluable después , si se podría asumir que el hijo había permitido a la vía de Dos de la infraestructura de tres manera de una lucha
#
# Epoch 00021: loss improved from 1.03320 to 1.03141, saving model to /content/drive/MyDrive/Modelos/4LSTM_ADAM_MIXED22_CAP_CHECKPOINT.h5
# Epoch 22/200
# 4658/4658 [==============================] - 357s 77ms/step - loss: 1.0248
# Temp 0.2
# El gobierno ha querido expropiar el legado de Francisco I y probablemente , el poder de manera Casanova e incluso . < > Ahora hoy , el gobierno de la presidencia en México se trata de los derechos privados . En este contexto , se tiene un mismo apoyo histórico , de ahí ha sido el presidente más sobre una de Fidel , el presidente que no se hace , , por costa de ahí el gasto público . No es un servidor político y solo un plan de saturación , y es cualquier voluntad más que es oír ,
# Temp 0.33
# El mercado energético tejano rebasa los sueños más guajiros de los neoliberales más dogmáticos . En aquel estado del sur de los Estados Unidos existen más de 200 público los artículos aquí son relevante para construir otras mentes de personas y voluntades , como lo hizo una conversación que se lo coloca para cualquier país irrestricto , el margen del INE no puede ser ahí ni más que quizá de sus familias no se ha combatido no puede lograrse . El lopezobradorismo está bien para un sentido antes de que es los temas comerciales y resultado para la gran mayoría
# Temp 0.5
# El gobierno ha querido expropiar el legado de Francisco I y probablemente no suele resolver a un hombre de Itzel arbitrariamente . < > El principal de los Estados los gobernadores también ha hecho una medida de López Obrador en que la SCJN electoral ; se tiene más importante que la política en la conciencia nacional " . Notas y el margen de la corrupción y la corrupción , el Presidente que nos tiene ante la Casa Blanca . Se han evidenciado la 4T . A la misma agenda de la Ley de la Industria la expresión , en la
#
# Epoch 00022: loss improved from 1.03141 to 1.02483, saving model to /content/drive/MyDrive/Modelos/4LSTM_ADAM_MIXED22_CAP_CHECKPOINT.h5
# Epoch
# El pasado viernes , 15 de enero el Instituto Nacional Electoral ( INE ) acordó censurar al Presidente de la República y permitiría que la sociedad frente al viejo régimen . < > Ya hoy Cienfuegos y responden el partido financiero de manera Financiero en manera internacionales y ello no ha sido sembrados , Denise fieles en los que se han vuelto . Para nosotros sería un cambio preciso para una necesidad del término había buenas país y mujeres para generar una crisis que , por todos los beneficiarios mexicanos que justifican por los medios del mundo . Pronto los
# Temp 0.5
# ...
# Temp 0.33
# El gobierno ha querido expropiar el legado de Francisco I . Madero . En un momento de la conversación contra un enorme desconocimiento para darle su libertad , con el fin de los programas de agradecimiento en un sector nacional que amplio de ti se advierte fuera en el fin de beneficiar a favor de su población . < > Y el mismo neoliberal de favor de los principales vacunas del INE como más de un < i > Excélsior < \i > de Julio Scherer el historiador Daniel Manuel López Obrador . Hace algo de juicio debe , toda
# Temp 0.5
# Yo debería un inmigrante en el que el pasado Andrés Manuel López Obrador a sus pretensiones del capítulo tiempo demostró en el sentido . En septiembre de 2014 el Contralmirante mi día de ser York que era ayer . Ha llegado la pobreza y lograr un foro comercial , para un gobierno que no puede pagar una frase de fuerza de la economía . La política misma datos que importa sin haber un efecto para ser más importante para la democracia . Si lo que nos ve públicos ni se interesó las soluciones que el poder es una obligación de
#
# Epoch 00192: loss did not improve from 0.62502
# Epoch 193/200
# 4658/4658 [==============================] - 187s 40ms/step - loss: 0.6246
# Temp 0.2
# La democracia consiste en partidos que pierden elecciones . Así de simple , así que sólo en un momento de gobierno aprovechándose de la pandemia , como una cifra de producción se vuelva más de una versión de los dos . Ojalá en todo hay razón en el país como siempre una opción mayor . Las reglas de mujeres , desde los avances en el que se están presentando . Pero se está construyendo un problema que se volvió de forma públicas . En una democracia , el presidente de este país esa opción no podría ser enjuiciado o .
# Temp 0.33
# El gobierno ha querido expropiar la palabra liberal . Es imposible . Toda la historia del liberalismo mexicano fue una lucha por defender principios que el gobierno viola , desvirtúa , pervierte y corrompe . Acá una muestra mínima del pensamiento liberal en el siglo XIX . < b > Contra el poder absoluto < \b > . " Nada más importante para una nación que ha adoptado el sistema republicano [ . . ] que disminuir los motivos reales o aparentes que puedan acumular una gran masa de autoridad y poder en manos de un solo hombre [ .
# Temp 0.5
# El presidente electo , Andrés Manuel López Obrador , inició una gira de agradecimiento por la política de la Suprema Corte de Justicia del sistema mexicano de encima de los votos y los despachos del Estado de derecho y de Sedesol y y los países sociales con un conjunto muy en la vida ? También nos resolver a ese libro que le saben una gran conversación . Los partidos y los héroes de los propios y los candidatos se han comprometido de cabo los temas del mundo y de respeto , en modo de los proyectos de comunicación tendrían poner
#
# Epoch 00193: loss improved from 0.62502 to 0.62458, saving model to /content/drive/MyDrive/Modelos/4LSTM_ADAM_MIXED22_CAP_CHECKPOINT.h5
# Epoch 194/200
# 4658/4658 [==============================] - 171s 37ms/step - loss: 0.6229
# Temp 0.2
# El principal riesgo para la libertad de expresión en el mundo ya no son los gobiernos sino que ya nadie hace un porcentaje del país sino una misión de guerra . El país se parece historia para gobernador para uno de los trabajadores internacionales . Por eso se vacuna a cabo que nuestro sistema actual no ha ocurrido como lo suyo y hoy cuentan con un médico que esté obligado para hacer . Basta con que el asunto esa opción es muchos años : a eso lleva un tema histórico . Por todos sirve el dolor de disciplina se le
# Temp 0.33
# El lunes 28 de septiembre del 2020 , la Secretaría de Seguridad Ciudadana de la Ciudad de México ( SSC CdMx ) desplegó un impresionante operativo para contener la manifestación que se celebró a propósito del Día Global para Defender el Derecho al Aborto . En esa jornada participaron aproximadamente seis elementos de policía por cada persona manifestante . Destacó el papel desempeñado por un grupo policial integrado solo por los pobres para salvar el viejo régimen en Pemex , 2021 será el ex artículo Secretario de la campaña de comunicación en los Estados Unidos , pero no sólo la
# Temp 0.5
# En busca de inspiración para estos días de miedo e incertidumbre , he recordado la trayectoria de un héroe de la medicina en México : el doctor Jesús Kumate Rodríguez . A veces los desastres naturales sacan lo mejor del ser humano : la corrupción , del presidente se llevaron de cuenta sobre la migración de perder el barco . La iniciativa tiene propiciará las autoridades políticas de García iguales . Los dos mexicanos en los Estados Unidos ya se llevó a ser menos de la diferentes estrategia de nuestra investigación . < > Los países se ha hecho que
#
# Epoch 00194: loss improved from 0.62458 to 0.62292, saving model to /content/drive/MyDrive/Modelos/4LSTM_ADAM_MIXED22_CAP_CHECKPOINT.h5
# Epoch 195/200
# 4658/4658 [==============================] - 167s 36ms/step - loss: 0.6243
# Temp 0.2
# El proyecto del General Salvador Cienfuegos a México confirma una vez más la enorme fortaleza de la política exterior del país como los jefes de representación particulares que al presunto compromiso político se observa a la profundidad de los procesos privados . El poder es esa lógica de más de trastocarlo las decisiones de los proyectos de origen para el gobierno para los lácteos , el despotismo y su salud , sus más más numerosas para la soberanía que no puede resolver que el presidente no quedó proveyó sectores más bajo el mal de sus propósitos . Y sin duda
# Temp 0.33
# El principal riesgo para la libertad de expresión en el mundo ya no son los gobiernos sino las monstruosas empresas digitales transnacionales . Los algoritmos de Google , Facebook , Instagram , Twitter y Youtube , entre otros , hoy determinan lo que vemos o no en nuestras pantallas . Y los ejecutivos y las ejecutivas de estas empresas deciden de manera unilateral lo que se considera como una comunicación válida o prohibida . < > La censura de parte de Twitter de tres destacadas cuentas cercanas a la Cuarta Transformación ( véase : https : / / bit .
# Temp 0.5
# El retorno del General Salvador Cienfuegos a México confirma un gobierno de partido es un gobierno de partido con una administración de favor de respeto a la ciudadanía contra el Tren Maya . Más de manera Fernández para el gobierno de cada país único poner como poder para que al gobierno mexicano no tiene sus cosas de forma y un pueblo está de Estados tipo de pesos . El Partido operandi de contar el Poder Oficial de la República con los organismos autónomos dentro del tema se de realizar nuevas víctimas de sus cargos de acuerdo que México se encuentran
#
# Epoch 00195: loss did not improve from 0.62292
# Epoch 196/200
# 4658/4658 [==============================] - 162s 35ms/step - loss: 0.6181
# Temp 0.2
# El gobierno ha querido expropiar el legado de Francisco I . Madero . Es imposible . La vida de Madero fue una lucha por defender principios que el actual gobierno desvirtúa , pervierte y corrompe . Solo falta que viole el lema maderista " Sufragio efectivo , no reelección " . Acá una muestra mínima del pensamiento maderista . " Siempre es peligroso para los pueblos dejar todo el poder en manos de un solo hombre " . < i > La sucesión presidencial en 1910 < \i > , 1909 . " Son raros los que , con el
# Temp 0.33
# El presidente electo , Andrés Manuel López Obrador : inició una gira de agradecimiento por el país . Parece que seguimos en campaña . A cada crítica que se le hace a las propuestas o las acciones de la nueva administración y la batalla para ser víctimas del país . Sin embargo , los conservadores se encuentran en esta vez de Canadá en las que se públicas más de sus planes de Estado para las denuncias con nuestro artículo nivel nacional . Todo se abre la Constitución , pero no se incrementarán la política . Las personas han sido clientes
