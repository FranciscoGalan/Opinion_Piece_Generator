# %%
# When running on colab remember to use a GPU enviroment
import numpy as np
import re  
from keras.layers import Dense, LSTM, Input, Embedding, Dropout
from keras.utils import np_utils
from keras.models import Model, load_model
from keras.optimizers import Adam
from keras.preprocessing.text import Tokenizer
from keras.callbacks import LambdaCallback
from keras.callbacks import ModelCheckpoint

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# We are loading the file with texts from all the authors, be sure to select the file you want
with open ('/content/drive/MyDrive/Modelos/mixed_text.txt', encoding='utf-8-sig') as f:
    text = f.read()
seq_length = 20
text = text[:int(len(text)/2.5)]
start_story = '| ' * seq_length
text = start_story + text

# %%
def clean_text(text):
    """This function will clean a text in order to make it suitable for the LSTM model"""
    text = text.lower()
    text = text.replace('\n', ' ')
    text = re.sub('   +', '. ', text).strip()
    text = text.replace('..', '.')
    # This pattern will insert a space before any punctuation sign in order to also tokenize them
    text = re.sub('([!"#$%&()*+,-./:;<=>?@[\]^_`{|}~])', r' \1 ', text)
    text = re.sub('\s{2,}', ' ', text)

    return text

# %%
# Clean the text
text = clean_text(text)

# %%
# We create a Tokenizer object
tokenizer = Tokenizer(char_level = False, filters = '', lower = True)
# We fit our object with our text
tokenizer.fit_on_texts([text])
# We check how many words/tokens were found (+1 due zero indexing)
total_words = len(tokenizer.word_index) + 1
# We create a sequence of token labels for our text
token_list = tokenizer.texts_to_sequences([text])[0]

# %%
def generate_sequences(token_list, step, seq_length):
    """This function will generate a list of sequences from a tokenized text given a specific sequence length and a step"""
    X = []
    y = []

    # Given a specific tokenized text, X will save a word-sequence of n length and y will save the next word for that sequence
    for i in range(0, len(token_list) - seq_length, step):
        X.append(token_list[i: i + seq_length])
        y.append(token_list[i + seq_length])
    
    # y must be turned into categorical
    y = np_utils.to_categorical(y, num_classes = total_words)
    
    num_seq = len(X)
    print('Number of sequences:', num_seq, "\n")
    
    return X, y, num_seq

# %%
# Get your sequences
X, y, num_seq = generate_sequences(token_list, step = 1, seq_length = 20)
# Out:
# Number of sequences: 123311

# %%
# Transform sequence lists to np arrays
X = np.array(X)

# %%
# Transform sequence lists to np arrays
# Consider waiting a couple seconds before running this cell after the previous one due RAM usage
y = np.array(y)

# %% [markdown]
# ## Define the LSTM model

# %%
n_units = 256 # Space dimensions
embedding_size = 100 # Size of the embedding layer

# Input layer
text_in = Input(shape = (None,))
# Embedding layer
embedding = Embedding(total_words, embedding_size)
x = embedding(text_in)
# First LSTM layer
x = LSTM(n_units, return_sequences = True)(x)
# Dropout to avoid overfitting
x = Dropout(0.2)(x)
# Second LSTM layer
x = LSTM(n_units, return_sequences = True)(x)
x = Dropout(0.2)(x)
# Third LSTM layer
x = LSTM(n_units, return_sequences = True)(x)
x = Dropout(0.2)(x)
# Fourth LSTM layer
x = LSTM(n_units)(x)
x = Dropout(0.2)(x)
# Output layer
text_out = Dense(total_words, activation = 'softmax')(x)
# Model definition
model = Model(text_in, text_out)
# Compile with a crossentropy loss and an Adam optimizer 
model.compile(loss='categorical_crossentropy', optimizer='adam')

# %%
# Chek your model's structure
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, None)]            0
# _________________________________________________________________
# embedding (Embedding)        (None, None, 100)         1662900
# _________________________________________________________________
# lstm (LSTM)                  (None, None, 256)         365568
# _________________________________________________________________
# dropout (Dropout)            (None, None, 256)         0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, None, 256)         525312
# _________________________________________________________________
# dropout_1 (Dropout)          (None, None, 256)         0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, None, 256)         525312
# _________________________________________________________________
# dropout_2 (Dropout)          (None, None, 256)         0
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 256)               525312
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense (Dense)                (None, 16629)             4273653
# =================================================================
# Total params: 7,878,057
# Trainable params: 7,878,057
# Non-trainable params: 0
# _________________________________________________________________

# %%
def sample_with_temp(preds, temperature=1.0):
    """This function gets the predictions generated by a model and returns the best fit choosen a given temperature"""
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    # creates a random experiment given the probabilities for ou next word
    probas = np.random.multinomial(1, preds, 1)
    # return the word with more probability in our experiment 
    return np.argmax(probas)

# %%
def generate_text(seed_text, next_words, model, max_sequence_len, temp):
    """This function will generate a text of a given size using the predictions generated by our model"""
    output_text = seed_text
    
    seed_text = start_story + seed_text
    
    for _ in range(next_words):
      # Tokenize the seed text
        token_list = tokenizer.texts_to_sequences([seed_text])[0]
        token_list = token_list[-max_sequence_len:]
        token_list = np.reshape(token_list, (1, max_sequence_len))
        
        # get the predictions
        probs = model.predict(token_list, verbose=0)[0]
        # get the most probable next word 
        y_class = sample_with_temp(probs, temperature = temp)
        
        # if probability = 0 returns no word
        if y_class == 0:
            output_word = ''
        # if the probability is not 0     
        else:
            output_word = tokenizer.index_word[y_class]
                        
        output_text += output_word + ' '
        seed_text += output_word + ' '

    return output_text

# %%
def on_epoch_end(epoch, logs):
    """This function will generate a text prediction after each epoch using different temperatures"""
    seed_text = ""
    gen_words = 100

    print('Temp 0.2')
    print (generate_text(seed_text, gen_words, model, seq_length, temp = 0.2))
    print('Temp 0.33')
    print (generate_text(seed_text, gen_words, model, seq_length, temp = 0.33))
    print('Temp 0.5')
    print (generate_text(seed_text, gen_words, model, seq_length, temp = 0.5))

# This element will save our model after each epoch, only if it outperformed its previous loss score
filepath = '/content/drive/MyDrive/Modelos/4LSTM_ADAM_MIX_LOW_CHECKPOINT.h5'
checkpoint = ModelCheckpoint(filepath, monitor='loss', verbose=1, save_best_only=True, mode='min')

# %%
# Model Training
epochs = 200
batch_size = 32
num_batches = int(len(X) / batch_size)
callback = LambdaCallback(on_epoch_end=on_epoch_end)
callbacks_list = [callback, checkpoint]
model.fit(X, y, epochs=epochs, batch_size=batch_size, callbacks = callbacks_list, shuffle = True)
# Out:
# Epoch 1/200
# 3854/3854 [==============================] - 231s 53ms/step - loss: 7.2142
# Temp 0.2
# de y de de , . de de . . , . . . . . . el a . . de , . . . , , . . de , | . de , . de la . el la . de de , . y . . . de de no . . de , y y . , , . . de , . . de . que . . y , de de , . y . . . . . . de , el , . , , la . la . , y
# Temp 0.33
# que de de de el . . | , . y y a , , que | a . , el de | que , | . . la la y , y de que y , , , de a el , de la de . de . se . el de de y del de . . , la , y . de a . de que de . de no de para a , de . . que la , a . . la , , , . de de de de . | , . que
# Temp 0.5
# no . . las que . y , la la . , de . que . Y y a , . con no El de el y . . de si . . . que . | , no la a a . , , la el . . . , la no . la . el tiempo , , de de de la la por los el el a de de " , de y las el , la . los . , y y . , la el , de . . por . , y , de
#
# Epoch 00001: loss improved from inf to 7.10866, saving model to /content/drive/MyDrive/Modelos/4LSTM_ADAM_DENISSE_CAP_CHECKPOINT.h5
# Epoch 2/200
# 3854/3854 [==============================] - 176s 46ms/step - loss: 6.8934
# Temp 0.2
# . , de el . , , de . . de de , de . , , , que de de . el de , de . , . . , de , de , , que , , de la de de de . la , . de la de de la . de , , . la de . , , , , de , de , , , . de de . , de . , , . , de de , de , la . , . . , de . . . de . ,
# Temp 0.33
# la y de | , . la de . de , la de la . de la a de . de que | , la . que y la . , de , de la , de que de la de , , la , y de un de . en de . El la . . en " , la , . . de . el . a de . , , . de de de de . en , , la de . . la de , los . , , , que de , de , el
# Temp 0.5
# que . , que de que de , la la la , , la , o , se a , . , a . en , que a y a las . | . del ? , | de | el no de de que . , que y . , , , , y . | la . , de la , que , y . la . . , y , . , . la y | de que , y el , y no una | . en a . . , de y , es -
#
# Epoch 00002: loss improved from 7.10866 to 6.92278, saving model to /content/drive/MyDrive/Modelos/4LSTM_ADAM_DENISSE_CAP_CHECKPOINT.h5
# Epoch 3/200
# 3854/3854 [==============================] - 105s 27ms/step - loss: 6.8693
# Temp 0.2
# , . la . de . , , por , , . la , , que de . de la de . , . , , de , . de . de , la de , , , . . de . . . de . , . la de de , . . de de , , , . , . . de , . , . . . de , , de . . de de de . la . . la . de , , , , , la de . , . de de . .
# Temp 0.33
# , de la . . de la de de la el a y , , . , de , la , de la , , , a que . , las la . la y de de de . . . que , . , . , la de de la , de . . de , la . | de . , se , la de , la la , y de de de . . de , | de de . de , de , . la . . . . , de de , el de ,
# Temp 0.5
# se . la , . " de , de el de . la la de de para | y a lo que de , , , . los . los de de el de , la Pero de y . la , para , de el . la a de el | y de | . la y , a y , la y , que la el de que la , la de la el y . de que al la la la . la la de . de , a la para no que y de de .
#
# Epoch 00003: loss improved from 6.92278 to 6.89524, saving model to /content/drive/MyDrive/Modelos/4LSTM_ADAM_DENISSE_CAP_CHECKPOINT.h5
# Epoch 4/200
# 3854/3854 [==============================] - 105s 27ms/step - loss: 6.8784
# Temp 0.2
# , de de . . de que . , . . . . | de la la . de la , . la de la . la de , la . de de la . de la . , , , la , , la . . de , , de la de la de la de de . de , de . la de . . . . de , de . de de . . . . , , de . de . . . , , . | . . . , la . , . ,
# Temp 0.33
# , de la de el de el | la la | la con , que la , , la . . , . , . y , el la , la la la la . la el . | la , a de de la y , . de que . de de , la . . de - . . . . . la de la de en de de y de . y el la de . la de de . , , . la la , . , . de y , a de . , y
# Temp 0.5
# . de de | | . . . la la de que la y y , , . de del la de . | es de de de de y y la a el . de , | de , , . , , un que . de , que , . la la y los el y la a | de . | la el las la de el la al - , de que y de en . | un | . de en se de el de . que . la | la el que , |
#
# Epoch 00004: loss improved from 6.89524 to 6.88465, saving model to /content/drive/MyDrive/Modelos/4LSTM_ADAM_DENISSE_CAP_CHECKPOINT.h5
# Epoch 5/200
# 3854/3854 [==============================] - 104s 27ms/step - loss: 6.8430
# Temp 0.2
# , y , de la de a . , , . la de la de la , que la . . , , de de , de , de , . la la . la , , , de la de de de . , que de la de | , . . , de . de la el , . . , de . la , la , , . la . . . . de , . , el , , , la de , la , . la la . , , . . , la .
# Temp 0.33
# , que y el de . . . y . . , , , . , . el de . la . , la . . la que . , que a , . , el la de la , de , , | , la | , de . a de de , | el la y la la , . , . . que la la . de , la la , . la de , , . . . , de . de a de . . de | que la la y y la que el
# Temp 0.5
# | de la . , de , no la . " , . , que de de , . la . . . de y la , . . la de las los en su que que de . la por . . . la a del de en la No que . , de las que . de y que de , para y la la . , de no | no , , , , en de . que de la en de a . , - para la . felicitación . de la la la a ,
#
# Epoch 00005: loss improved from 6.88465 to 6.85699, saving model to /content/drive/MyDrive/Modelos/4LSTM_ADAM_DENISSE_CAP_CHECKPOINT.h5
# Epoch 6/200
# 3854/3854 [==============================] - 107s 28ms/step - loss: 6.8389
# Temp 0.2
# . . , de de que . , , y , de la de , . de de . de , , . , . de , . , , . el . , de . de , la . de , de . , . . de . la . , . . , . de , , que , de , . , de , , , . de , . la la . , , . , , , de de , , . . , de , , . . . la de de , |
# Temp 0.33
# de de la , , , de . . , . , , | , la , de , , . de , , . . la . , , de , de en y del . . a . , de de de , . , , . , , , de de . la . de de : que , y . | . . y la que la la , , | que de . el , . . y , de de , . , y . . de el . la de , en ,
# Temp 0.5
# . en la , no . la la de , | , . , la de de de . , con , corrupción . a . , la la . , No . de , y , la la el , . de y | . la de . . , , el a en y de , y que , , , . , de de en de que . la , , . . y de . la . a la , sobre y de e . . de . de , , la con , | |
#
# Epoch 00006: loss improved from 6.85699 to 6.84334, saving model to /content/drive/MyDrive/Modelos/4LSTM_ADAM_DENISSE_CAP_CHECKPOINT.h5
# Epoch 7/200
# 3854/3854 [==============================] - 110s 28ms/step - loss: 6.8114
# Temp 0.2
# de . . de | de de de de , de la . . de la . . , . de y . de . . , a de , de . , , , , de . , . de , , . , de . . el . , de de , , . . la , de , de . . de , . , . , , , . . , . de . , la de la , . , , . la . , , , . . de , de que , ,
# Temp 0.33
# . de de , . . . | de . . , el que de la de a . y , | una . de de el la , , el . . , . y la de . y . . , el , . y de de , de . . , y una , la que el , , , . de la para . , y . , , , , . la , , . , , , , de . . a , de , de , de de . , la , |
# Temp 0.5
# el , , de de | , , , que , . La una la . es de de . . . , para y , a la , . de y que , la de . su . , , a en , , . . con que , . , y . por . que . equipo . que , . en de no , con la de la de su la , de México | no | . el la . de | que de de de la . | . | , , . de para
#
# Epoch 00007: loss improved from 6.84334 to 6.83403, saving model to /content/drive/MyDrive/Modelos/4LSTM_ADAM_DENISSE_CAP_CHECKPOINT.h5
# Epoch 8/200
# 3854/3854 [==============================] - 103s 27ms/step - loss: 6.7994
# Temp 0.2
# de de de de , , , , la . . . , . de y de . de la . . de de . . la de . la , de de . . . de . . . , , , la de , el . de . de de . . que de de . de , la . . de , que , de la . de , . , de de de . . , de . la , . . que . de . la . los de de de . de de .
# Temp 0.33
# de . la . de . de . de , , de la las . la . la la . de de . de la , de . , de . . la . . , de , . de de de , el de de | , . de , , . a " de de , . . la , de . , de , . de la que . el . de de la la , de . de . a de la , el la de el . de . de de , de . y
# Temp 0.5
# la la y el y y en , la , a de y de de a , . que . una a de de . de que | la la el , | , de de la la , más los de los de . . en no , , que los . la el en | ha . . de de el , , una a el , | . de , el y la , no . , para el . , | , , de " . , de la la y , . de la el
#
# Epoch 00008: loss improved from 6.83403 to 6.80821, saving model to /content/drive/MyDrive/Modelos/4LSTM_ADAM_DENISSE_CAP_CHECKPOINT.h5
# Epoch 9/200
# 3854/3854 [==============================] - 103s 27ms/step - loss: 6.7679
# Temp 0.2
# la de . de , de . . de , , , de , . , . . . . , de | , . . de . de , de , de . . . de . la de de de la , , . , . , , de . . . . , de la de de . , . la . la , . . . de , . de . , de de el . . y la de , la . , la , . de . , . . de . de de
# Temp 0.33
# en . López , la , la . . y de la y . de lo de , , , la la la . de , de , la la , la , , de la que que . de , la de . la de de la , . . de de de . , de , en que de . el y que , de de , la que de de de , la . , . , de , , la que . la los de de . . de la , la de la de .
# Temp 0.5
# de de el . , , . la . la de " y . de , de de el la de no la , de , , el de . de de | , , la a | , . del y de . . que de . de la la la - y y , . . , de la . . . de la a que la . de de por la , de ; . , . , un los de y . la . cuentas , y que | . . a pensando y , |
#
# Epoch 00009: loss improved from 6.80821 to 6.78255, saving model to /content/drive/MyDrive/Modelos/4LSTM_ADAM_DENISSE_CAP_CHECKPOINT.h5
# Epoch 10/200
# 3854/3854 [==============================] - 108s 28ms/step - loss: 6.7281
# Temp 0.2
# . , , de , de de . , , , de de , de de de de de la , de . y . de de . , , de . , , de . , de y la , la de y de el la de , , . , , . , a de . . , , . , . de de . de . , , , , el que de , . de , . de que , . . de . , . de de que , de . , . de .
# Temp 0.33
# . de de de , . . . el la . , , . , , , de , . de , . en . de y | . la . el | la de . , la de . para de . | | de la , de . , , de , de , la , , . de de que . de . que de de de . , . . el la | de de la de de la | de , los de . de . de , , , de el | . .
# Temp 0.5
# , el , El . de Manuel . los un se de . , de de , . de de el , la , . de el . , AMLO de la de . los que a en la los . la . . a , y y que que de de a la que con de , de . , | . . . de y y y , no , . de y , de | , de el . y la de , , , a . , de . en de el que el . a
#
# Epoch 00010: loss improved from 6.78255 to 6.75211, saving model to /content/drive/MyDrive/Modelos/4LSTM_ADAM_DENISSE_CAP_CHECKPOINT.h5
# Epoch 11/200
# 3854/3854 [==============================] - 107s 28ms/step - loss: 6.6976
# Temp 0.2
# . , de . . . , de , de . . . de . de . , . , de , de , . de . , , la y la la , de de , , , . de . . , . . , . , , de , la , , . de la la la , de , de , . de , , . , . de , . , . la la de de a . , de de de de , , de de . , , de , , . no
# Temp 0.33
# de . . la . de . de , de , de la . . . , , de de , de . . . . de . la , y de de la la que , . la la la , . . . la la , de a la a . , de de , la . , de de , , . . que de . , , , , . la de en la de , la la de la la , . . , , , . de . , . , . de que
# Temp 0.5
# de , de de . que de la de . . , y . " es la lo . No para es , , la a de . el de de , a | la . , y con . de la que de . , | la por la , , de de el de . . , el | de para la de | . , la la que las de la . . | de , , . de . | de las el , . . que de en , de | la la , |
#
# Epoch 00011: loss improved from 6.75211 to 6.71984, saving model to /content/drive/MyDrive/Modelos/4LSTM_ADAM_DENISSE_CAP_CHECKPOINT.h5
# Epoch 12/200
# 3854/3854 [==============================] - 106s 27ms/step - loss: 6.6720
# Temp 0.2
# . , , . . . de , . , de de , . . , de . la , de . . la , . , , de . de , la , . de . , | el , . | que . . de , . . , , , . , . . de de , la la , que de de a de . . , , , . la , . . . , de . . , . , . . la , , , | de , . de . , ,
# Temp 0.33
# , , de de , . de , de . , , . de , de . el de . que de . . | la , de . de de la . la y . y . a la a , , , la no que , , la . de la de . . se . , de . , la . , | , , que de de de . , los de , de el la a . , que , de . . . de la de de de . de de . la .
# Temp 0.5
# , . el de , en de . . . de en la y de de la el . , , , . a de . el el , una la . de los en los de que al la | de de | , y el de y , . , , . de que . , que poder . y . para y a , La los y , , el , . a . a . de . de de | , , , , de se que de , a las , que o el .
#
# Epoch 00012: loss improved from 6.71984 to 6.69760, saving model to /content/drive/MyDrive/Modelos/4LSTM_ADAM_DENISSE_CAP_CHECKPOINT.h5
# Epoch 13/200
# 3854/3854 [==============================] - 112s 29ms/step - loss: 6.6493
# Temp 0.2
# de de la . de . de . , de . . . de el . , , de . , de . , . de . , de , . . la de , . . de de . , , . de . la . | , de . . de la . . , . . , de , . la . . de . que . . . de de . , la de | , , , . de . de , . . , , . la de . la de de . .
# Temp 0.33
# . . la . de . de de , , de . . de , , de la , . . de . , , . , la . que de , . , , en | y , de . que | que . la , de , a el de . de . de la . , la , para , de a el la de a de , | | de . la la , . | , , . . | . . de . de que , de de , a de de . .
# Temp 0.5
# de de el que . de de y vez , , , . , más de Una , de y y los que . la la de y . del , | la que de de . de de . a . | . la , a a la si de , , , de de . la de el la . . . | . , , . de . , de la de . . , , de para más la que , en . , del la la . de en la de la , los de
#
# Epoch 00013: loss improved from 6.69760 to 6.66529, saving model to /content/drive/MyDrive/Modelos/4LSTM_ADAM_DENISSE_CAP_CHECKPOINT.h5
# Epoch
#
# Epoch 00198: loss did not improve from 0.44069
# Epoch 199/200
# 3854/3854 [==============================] - 187s 49ms/step - loss: 0.3964
# Temp 0.2
# La historia no se repite , pero sí instruye , escribe Timothy Snyder en Sobre la tiranía : Veinte lecciones del siglo XX . La usurpación del poder y la elusión de la ley por parte de un grupo o un individuo para sido propio daña a la democracia . Y la nuestra es tan frágil que es imperativo alertar ante las amenazas , provengan de donde provengan , y eso incluye las acciones de un gobierno legítimo y popular . No pretendo argumentar que López Obrador está erigiendo una tiranía , pero sí asume posiciones que deberían preocupar ;
# Temp 0.33
# La historia no se repite , pero sí instruye , escribe Timothy Snyder en Sobre la tiranía : Veinte lecciones del siglo XX . La usurpación del poder y la elusión de la ley por parte de un grupo o un individuo para sido propio daña a la democracia . Y la nuestra es tan frágil que es imperativo alertar ante las amenazas , provengan de donde provengan , y eso incluye las acciones de un gobierno legítimo y popular . No pretendo argumentar que López Obrador está erigiendo una tiranía , pero sí asume posiciones que deberían preocupar ;
# Temp 0.5
# Hoy el presidente de México tiene 86 % de aprobación . Es amado , adorado , idolatrado . Dondequiera que va la gente se agolpa para verlo , se amontona para tocarlo , hace cola para tomarse la " selfie " con él . Se le reconoce . Se le quiere . Se le percibe cercano y humano , austero y sincero . En sus giras peripatéticas es recibido con el mismo frenesí que las irregularidades y la " Federal " ? Si los que están obligado a serlo a los casos u lecciones , las programas sociales - cuando
#
# Epoch 00199: loss improved from 0.44069 to 0.43027, saving model to /content/drive/MyDrive/Modelos/4LSTM_ADAM_DENISSE_CAP_CHECKPOINT.h5
# Epoch 200/200
# 3854/3854 [==============================] - 187s 48ms/step - loss: 0.4026
# Temp 0.2
# El gobierno no se repite a la Suprema Corte de Justicia y la crisis de derecha , de una Suprema Corte , más penal , más que siempre afirma . Un problema es que el gobierno le asemeja a la vida pública . Pero el Estado es social que no como un acto de justicia distinto a manera que vive y la no contra la consulta democrática que puede ser algo impulsado , machista o acusados . No importa que desde la política de transparencia y propuestas como la Constitución y a eso y a través de la ley ,
# Temp 0.33
# México dividido . México polarizado . México conjugando el vocabulario de la confrontación : " fifís " y " chairos " y " señoritingos " y " pejezombies " y " neoporfiristas " y " canallines " y " chayoteros " y " AMLOvers " . La nación nuevamente disputada entre quienes celebran la refundación augurada y quienes temen cómo ocurrirá . Una elección presidencial en la cual el enojo con el statu quo se ha impuesto sobre el temor de cambiarlo . López Obrador probablemente será el próximo Presidente y no por la calidad de su campaña , la
# Temp 0.5
# La historia no se repite , pero sí instruye , escribe Timothy Snyder en Sobre la tiranía : Veinte lecciones del siglo XX . La usurpación del poder y la elusión de la ley por parte de un grupo o un individuo para beneficio propio daña a la democracia . Y la nuestra es tan frágil que es imperativo alertar ante las amenazas , provengan de donde provengan , y eso incluye las acciones de un gobierno legítimo y popular . No pretendo argumentar que López Obrador está erigiendo una tiranía , pero sí asume posiciones que deberían preocupar ;
#
# Epoch 00200: loss did not improve from 0.43027

# %%
# Save our final model
model.save('/content/drive/MyDrive/Modelos/4LSTM_ADAM_MIX_LOW_200E.h5')
